# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.2'

# %%
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the empty plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the empty plot with ax.plt() and plot the data
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()

ax.barh(x_axis, y_axis, color="cyan", label='Chicago')
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.scatter(y_axis, x_axis, color = "red", label = "Chicago")
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")

plt.xlim(0, 50)

# Add the legend.
plt.legend()

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
x_axis
y_axis
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color="skyblue",alpha=0.8, edgecolors="black", label='Boston', s = [i * 5 for i in y_axis], linewidths=2)
plt.gca().invert_yaxis()
# Create labels for the x and y axes.
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.xlim(0, 50)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2177fd3c430>,
#   <matplotlib.patches.Wedge at 0x2177fd3c970>,
#   <matplotlib.patches.Wedge at 0x2177fd3cf70>,
#   <matplotlib.patches.Wedge at 0x2177fd4b5b0>,
#   <matplotlib.patches.Wedge at 0x2177fd4bbb0>,
#   <matplotlib.patches.Wedge at 0x2177fd5a1f0>,
#   <matplotlib.patches.Wedge at 0x2177fd5a7f0>,
#   <matplotlib.patches.Wedge at 0x2177fd5adf0>,
#   <matplotlib.patches.Wedge at 0x2177fd68430>,
#   <matplotlib.patches.Wedge at 0x2177fd68a30>,
#   <matplotlib.patches.Wedge at 0x2177fd13310>,
#   <matplotlib.patches.Wedge at 0x2177fd775e0>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
# Create the same pie chart using Object-Oriented Method
fig, ax = plt.subplots()
explode_values_2 = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis,labels=x_axis, explode=explode_values_2, startangle=90, counterclock=False, shadow=True, radius=2, autopct='%.1f%%', colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x2170547a220>,
#   <matplotlib.patches.Wedge at 0x21705474a60>,
#   <matplotlib.patches.Wedge at 0x2170538f4f0>,
#   <matplotlib.patches.Wedge at 0x2170538f760>,
#   <matplotlib.patches.Wedge at 0x21705539550>,
#   <matplotlib.patches.Wedge at 0x21705539e20>,
#   <matplotlib.patches.Wedge at 0x21705546730>,
#   <matplotlib.patches.Wedge at 0x21705546fa0>,
#   <matplotlib.patches.Wedge at 0x21705555910>,
#   <matplotlib.patches.Wedge at 0x21705563220>,
#   <matplotlib.patches.Wedge at 0x217055639a0>,
#   <matplotlib.patches.Wedge at 0x217055732b0>],
#  [Text(0.22875705114838243, 2.1880745443311334, 'Jan'),
#   Text(0.9568103219507245, 1.9810386184546105, 'Feb'),
#   Text(2.137888717223311, 1.0906107613485512, 'Mar'),
#   Text(2.0991008203502, -0.6586165394257254, 'April'),
#   Text(1.1729386483210522, -1.8612401584091138, 'May'),
#   Text(-0.1209286890490553, -2.196673906651799, 'June'),
#   Text(-1.707652687243523, -1.6863932814589768, 'July'),
#   Text(-2.1499118708813634, -0.4667750501509237, 'Aug'),
#   Text(-2.199595320049036, 0.04219511841882563, 'Sept'),
#   Text(-1.9974946719008249, 0.921962599961526, 'Oct'),
#   Text(-1.3014768208680605, 1.7737412677003281, 'Nov'),
#   Text(-0.45615292769668736, 2.1521906296965754, 'Dec')],
#  [Text(0.12477657335366313, 1.1934952059987998, '3.3%'),
#   Text(0.5218965392458497, 1.0805665191570601, '7.7%'),
#   Text(1.247101751713598, 0.6361896107866547, '13.0%'),
#   Text(1.1449640838273818, -0.3592453851413047, '11.7%'),
#   Text(0.6397847172660285, -1.0152219045867892, '10.7%'),
#   Text(-0.06596110311766651, -1.1981857672646177, '8.9%'),
#   Text(-0.9961307342253882, -0.9837294141844031, '14.5%'),
#   Text(-1.1726792022989252, -0.2546045728095947, '3.5%'),
#   Text(-1.1997792654812924, 0.02301551913754125, '3.9%'),
#   Text(-1.0895425483095407, 0.502888690888105, '9.2%'),
#   Text(-0.7098964477462147, 0.9674952369274517, '6.9%'),
#   Text(-0.2488106878345567, 1.1739221616526774, '6.6%')])
